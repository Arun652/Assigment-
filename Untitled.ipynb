# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
a=np.arange(40,50)
b=np.arange(50,60)
plt.plot(a,b)
plt.title("Q1")
plt.xlabel("a")
plt.ylabel("b")
# Out:
# Text(0, 0.5, 'b')
